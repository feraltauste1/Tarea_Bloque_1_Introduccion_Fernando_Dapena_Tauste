# %%
import numpy as np
import pandas as pd
from scipy import stats
import yfinance as yf
import os, sys, json, math, random, logging, enum
import requests


class APIs:

    def call_API(self):
        self.tickers = []
        self.data_yf = yf.download(["tickers"], start=2024-1-1, end=2025-30-12)
       
print("Hello world")
print("Hola mundo")
 
hola = (1,2,3,45)

set = 100

for num in hola:
    set += num

print(set)
# Out:
# Hello world
# Hola mundo
# 151
